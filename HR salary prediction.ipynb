# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("salarydata.csv")

# %%
data.head()
# Out:
#    age         workclass  education  education-num      marital-status  \
# 0   39         State-gov  Bachelors             13       Never-married
# 1   50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2   38           Private    HS-grad              9            Divorced
# 3   53           Private       11th              7  Married-civ-spouse
# 4   28           Private  Bachelors             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country salary
# 0             0              40  United-States  <=50K
# ...

# %%
data.shape
# Out:
# (32561, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   education       32561 non-null  object
#  3   education-num   32561 non-null  int64
#  4   marital-status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital-gain    32561 non-null  int64
#  10  capital-loss    32561 non-null  int64
#  11  hours-per-week  32561 non-null  int64
#  12  native-country  32561 non-null  object
#  13  salary          32561 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB

# %%
data.describe()
# Out:
#                 age  education-num  capital-gain  capital-loss  hours-per-week
# count  32561.000000   32561.000000  32561.000000  32561.000000    32561.000000
# mean      38.581647      10.080679   1077.648844     87.303830       40.437456
# std       13.640433       2.572720   7385.292085    402.960219       12.347429
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       48.000000      12.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000

# %%
#checking null values
data.isna().sum()
# Out:
# age               0
# workclass         0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
#checking data types
data.dtypes
# Out:
# age                int64
# workclass         object
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
data.tail()
# Out:
#        age     workclass   education  education-num      marital-status  \
# 32556   27       Private  Assoc-acdm             12  Married-civ-spouse
# 32557   40       Private     HS-grad              9  Married-civ-spouse
# 32558   58       Private     HS-grad              9             Widowed
# 32559   22       Private     HS-grad              9       Never-married
# 32560   52  Self-emp-inc     HS-grad              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 32556       Tech-support         Wife  White  Female             0
# 32557  Machine-op-inspct      Husband  White    Male             0
# 32558       Adm-clerical    Unmarried  White  Female             0
# 32559       Adm-clerical    Own-child  White    Male             0
# 32560    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 32556             0              38  United-States  <=50K
# ...

# %%
data.nunique()
# Out:
# age                73
# workclass           9
# education          16
# education-num      16
# marital-status      7
# occupation         15
# relationship        6
# race                5
# sex                 2
# capital-gain      119
# capital-loss       92
# hours-per-week     94
# native-country     42
# salary              2
# dtype: int64

# %%
data.value_counts('workclass')
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# dtype: int64

# %%
data['workclass']=data['workclass'].replace('?','private')

# %%
data.value_counts('workclass')
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# private              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# dtype: int64

# %%
data.value_counts('education')
# Out:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# dtype: int64

# %%
data.value_counts('education-num')
# Out:
# education-num
# 9     10501
# 10     7291
# 13     5355
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# dtype: int64

# %%
data.value_counts('marital-status')
# Out:
# marital-status
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# dtype: int64

# %%
data.value_counts('occupation')
# Out:
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# dtype: int64

# %%
data['occupation']=data['occupation'].replace('?','Prof-specialty')

# %%
data.value_counts('occupation')
# Out:
# occupation
# Prof-specialty       5983
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# dtype: int64

# %%
data.value_counts('relationship')
# Out:
# relationship
# Husband           13193
# Not-in-family      8305
# Own-child          5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# dtype: int64

# %%
data.value_counts('race')
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# dtype: int64

# %%
data.value_counts('sex')
# Out:
# sex
# Male      21790
# Female    10771
# dtype: int64

# %%
data.value_counts('capital-gain')
# Out:
# capital-gain
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 2538         1
# 5060         1
# 1639         1
# 4931         1
# 2387         1
# Length: 119, dtype: int64

# %%
data.value_counts('capital-loss')
# Out:
# capital-loss
# 0       31042
# 1902      202
# 1977      168
# 1887      159
# 1485       51
#         ...
# 2201        1
# 2163        1
# 1944        1
# 1539        1
# 2472        1
# Length: 92, dtype: int64

# %%
data.value_counts('hours-per-week')
# Out:
# hours-per-week
# 40    15217
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 74        1
# 87        1
# 92        1
# 94        1
# 82        1
# Length: 94, dtype: int64

# %%
data.value_counts('native-country')
# Out:
# native-country
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# ...

# %%
data['native-country']=data['native-country'].replace('?','United-States ')

# %%
data.value_counts('native-country')
# Out:
# native-country
# United-States                 29170
# Mexico                          643
# United-States                   583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# ...

# %%
data.value_counts('salary')
# Out:
# salary
# <=50K    24720
# >50K      7841
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   education       32561 non-null  object
#  3   education-num   32561 non-null  int64
#  4   marital-status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital-gain    32561 non-null  int64
#  10  capital-loss    32561 non-null  int64
#  11  hours-per-week  32561 non-null  int64
#  12  native-country  32561 non-null  object
#  13  salary          32561 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for i in ['age','education-num','capital-gain','capital-loss','hours-per-week']:
    plt.figure()
    data.boxplot([i])

# %%
Q1=np.percentile(data['age'],25,interpolation='midpoint')
Q2=np.percentile(data['age'],50,interpolation='midpoint')
Q3=np.percentile(data['age'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 28.0
# 37.0
# 48.0

# %%
data['age'].median()
# Out:
# 37.0

# %%
IQR=Q3-Q1

# %%
low=Q1-1.5*IQR
up=Q3+1.5*IQR

# %%
print(low)
print(up)
# Out:
# -2.0
# 78.0

# %%
outliers=[]
for x in data['age']:
    if ((x>up)or(x<low)):
        outliers.append(x)

# %%
outliers
# Out:
# [79,
#  90,
#  80,
#  81,
#  90,
#  88,
#  90,
#  90,
#  80,
#  90,
#  81,
#  82,
#  79,
#  81,
#  80,
#  83,
#  90,
#  90,
#  79,
#  81,
#  90,
#  90,
#  80,
#  90,
#  90,
#  79,
#  79,
#  84,
#  90,
#  80,
#  90,
#  81,
#  83,
#  84,
#  81,
#  79,
#  85,
#  82,
#  79,
#  80,
#  90,
#  90,
#  90,
#  84,
#  80,
#  90,
#  90,
#  79,
#  84,
#  90,
#  79,
#  90,
#  90,
#  90,
#  82,
#  81,
#  90,
#  84,
#  79,
#  81,
#  82,
#  81,
#  80,
#  90,
#  80,
#  84,
#  82,
#  79,
#  90,
#  84,
#  90,
#  83,
#  79,
#  81,
#  80,
#  79,
#  80,
#  79,
#  80,
#  90,
#  90,
#  80,
#  90,
#  90,
#  81,
#  83,
#  82,
#  90,
#  90,
#  81,
#  80,
#  80,
#  90,
#  79,
#  80,
#  82,
#  85,
#  80,
#  79,
#  90,
#  81,
#  79,
#  80,
#  79,
#  81,
#  82,
#  88,
#  90,
#  82,
#  88,
#  84,
#  83,
#  79,
#  86,
#  90,
#  90,
#  82,
#  83,
#  81,
#  79,
#  90,
#  80,
#  81,
#  79,
#  84,
#  84,
#  79,
#  90,
#  80,
#  81,
#  81,
#  81,
#  90,
#  87,
#  90,
#  80,
#  80,
#  82,
#  90,
#  90,
#  85,
#  82,
# ...

# %%
ind1=(data['age']>up)|(data['age']<low)
out=data.loc[ind1].index

# %%
out
# Out:
# Int64Index([   74,   222,   430,   918,  1040,  1168,  1935,  2303,  2754,
#              2891,
#             ...
#             31432, 31696, 31814, 31836, 31855, 32277, 32367, 32459, 32494,
#             32525],
#            dtype='int64', length=143)

# %%
data.drop(out,inplace=True)

# %%
plt.boxplot(data['age'])
plt.title('box plot')
# Out:
# Text(0.5, 1.0, 'box plot')

# %%
Q1=np.percentile(data['education-num'],25,interpolation='midpoint')
Q2=np.percentile(data['education-num'],50,interpolation='midpoint')
Q3=np.percentile(data['education-num'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 9.0
# 10.0
# 12.0

# %%
IQR=Q3-Q1
low=Q1-1.5*IQR
up=Q3+1.5*IQR
print(low)
print(up)
# Out:
# 4.5
# 16.5

# %%
outliers=[]
for x in data['education-num']:
    if ((x>up)or(x<low)):
        outliers.append(x)
outliers
# Out:
# [4,
#  3,
#  4,
#  4,
#  2,
#  4,
#  3,
#  4,
#  2,
#  1,
#  4,
#  4,
#  3,
#  3,
#  3,
#  4,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  4,
#  4,
#  4,
#  3,
#  4,
#  4,
#  3,
#  3,
#  4,
#  3,
#  2,
#  1,
#  4,
#  4,
#  4,
#  4,
#  2,
#  2,
#  3,
#  3,
#  4,
#  3,
#  4,
#  3,
#  4,
#  4,
#  3,
#  2,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  2,
#  4,
#  4,
#  4,
#  4,
#  3,
#  3,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  3,
#  4,
#  4,
#  2,
#  2,
#  3,
#  3,
#  4,
#  3,
#  2,
#  4,
#  4,
#  3,
#  3,
#  2,
#  2,
#  4,
#  3,
#  4,
#  1,
#  4,
#  1,
#  4,
#  4,
#  4,
#  3,
#  3,
#  4,
#  3,
#  4,
#  4,
#  2,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  1,
#  4,
#  4,
#  4,
#  3,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  4,
#  3,
#  2,
#  4,
#  4,
#  4,
#  1,
#  3,
#  4,
#  4,
#  4,
#  4,
#  2,
#  2,
#  4,
#  4,
#  4,
#  2,
#  4,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  2,
#  4,
#  4,
#  4,
# ...

# %%
ind1=(data['education-num']>up)|(data['education-num']<low)
out=data.loc[ind1].index
out
# Out:
# Int64Index([   15,    56,    61,    79,   160,   183,   195,   214,   221,
#               224,
#             ...
#             32401, 32403, 32413, 32425, 32430, 32431, 32432, 32448, 32479,
#             32517],
#            dtype='int64', length=1177)

# %%
data.drop(out,inplace=True)
plt.boxplot(data['education-num'])
plt.title('box plot')
# Out:
# Text(0.5, 1.0, 'box plot')

# %%
Q1=np.percentile(data['hours-per-week'],25,interpolation='midpoint')
Q2=np.percentile(data['hours-per-week'],50,interpolation='midpoint')
Q3=np.percentile(data['hours-per-week'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 40.0
# 40.0
# 45.0

# %%
data['hours-per-week'].median()
# Out:
# 40.0

# %%
IQR=Q3-Q1
low=Q1-1.5*IQR
up=Q3+1.5*IQR
print(low)
print(up)

outliers=[]
for x in data['hours-per-week']:
    if ((x>up)or(x<low)):
        outliers.append(x)
outliers
# Out:
# 32.5
# 52.5
# [13,
#  16,
#  80,
#  30,
#  60,
#  20,
#  60,
#  80,
#  15,
#  25,
#  30,
#  60,
#  55,
#  60,
#  58,
#  32,
#  70,
#  2,
#  22,
#  30,
#  25,
#  60,
#  60,
#  32,
#  25,
#  56,
#  60,
#  28,
#  60,
#  60,
#  20,
#  30,
#  30,
#  24,
#  24,
#  2,
#  60,
#  16,
#  20,
#  25,
#  12,
#  65,
#  1,
#  28,
#  24,
#  55,
#  60,
#  12,
#  60,
#  55,
#  20,
#  10,
#  20,
#  55,
#  70,
#  20,
#  20,
#  60,
#  30,
#  20,
#  30,
#  60,
#  12,
#  75,
#  24,
#  24,
#  98,
#  15,
#  60,
#  56,
#  16,
#  60,
#  80,
#  25,
#  54,
#  25,
#  15,
#  24,
#  10,
#  15,
#  55,
#  60,
#  30,
#  20,
#  8,
#  25,
#  25,
#  30,
#  24,
#  55,
#  15,
#  15,
#  10,
#  10,
#  30,
#  25,
#  6,
#  16,
#  55,
#  64,
#  65,
#  25,
#  24,
#  60,
#  19,
#  30,
#  18,
#  60,
#  72,
#  25,
#  60,
#  28,
#  5,
#  55,
#  60,
#  20,
#  60,
#  16,
#  60,
#  24,
#  6,
#  30,
#  20,
#  20,
#  20,
#  60,
#  60,
#  25,
#  20,
#  20,
#  8,
#  20,
#  24,
#  80,
#  58,
#  9,
#  8,
#  20,
#  32,
#  55,
#  60,
#  12,
# ...

# %%
ind1=(data['hours-per-week']>up)|(data['hours-per-week']<low)
out=data.loc[ind1].index
out
# Out:
# Int64Index([    1,     6,    10,    12,    20,    21,    27,    28,    34,
#                37,
#             ...
#             32532, 32536, 32539, 32541, 32542, 32544, 32545, 32548, 32553,
#             32559],
#            dtype='int64', length=8592)

# %%
data.drop(out,inplace=True)
plt.boxplot(data['hours-per-week'])
plt.title('box plot')
# Out:
# Text(0.5, 1.0, 'box plot')

# %%
data.shape
# Out:
# (22649, 14)

# %%
data=data.drop('education',axis=1)

# %%
data.shape
# Out:
# (22649, 13)

# %%
data
# Out:
#        age     workclass  education-num      marital-status  \
# 0       39     State-gov             13       Never-married
# 2       38       Private              9            Divorced
# 3       53       Private              7  Married-civ-spouse
# 4       28       Private             13  Married-civ-spouse
# 5       37       Private             14  Married-civ-spouse
# ...    ...           ...            ...                 ...
# 32555   22       Private             10       Never-married
# 32556   27       Private             12  Married-civ-spouse
# 32557   40       Private              9  Married-civ-spouse
# 32558   58       Private              9             Widowed
# 32560   52  Self-emp-inc              9  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital-gain  \
# 0           Adm-clerical  Not-in-family  White    Male          2174
# 2      Handlers-cleaners  Not-in-family  White    Male             0
# ...

# %%
sns.countplot(data['salary'])
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %%
#label encoding
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
for i in ['workclass', 'marital-status',
       'occupation', 'relationship', 'race','native-country', 'salary','sex']:
    data[i] = label_encoder.fit_transform(data[i])

# %%
data
# Out:
#        age  workclass  education-num  marital-status  occupation  \
# 0       39          6             13               4           0
# 2       38          3              9               0           5
# 3       53          3              7               2           5
# 4       28          3             13               2           9
# 5       37          3             14               2           3
# ...    ...        ...            ...             ...         ...
# 32555   22          3             10               4          10
# 32556   27          3             12               2          12
# 32557   40          3              9               2           6
# 32558   58          3              9               6           0
# 32560   52          4              9               2           3
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0                 1     4    1          2174             0              40
# ...

# %%
data['workclass'].value_counts()
# Out:
# 3    16327
# 1     1621
# 5     1366
# 6      989
# 8      860
# 0      825
# 4      655
# 7        3
# 2        3
# Name: workclass, dtype: int64

# %%
plt.figure(figsize=(14,5))
sns.heatmap(data.corr(),vmin=0.1,vmax=0.9,annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

# %%
x=data.drop('salary',axis=1)
y=pd.DataFrame(data['salary'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train.values.ravel())
y_pred=lr.predict(x_test)
# Out:
# E:\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
print('accuracy: ',accuracy_score(y_test,y_pred))
# Out:
# accuracy:  0.7955849889624724

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train.values.ravel())
y_pred=lr.predict(x_test)
print('accuracy: ',accuracy_score(y_test,y_pred))
# Out:
# accuracy:  0.8099337748344371

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_values=[]
neighbors=np.arange(3,15)
for k in neighbors:
    classifier=KNeighborsClassifier(n_neighbors=k,metric='minkowski')
    classifier.fit(x_train,y_train)
    y_pred=classifier.predict(x_test)
    acc=accuracy_score(y_test,y_pred)
    acc_values.append(acc)
# Out:
# <ipython-input-73-a3aba1494452>:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   classifier.fit(x_train,y_train)
# <ipython-input-73-a3aba1494452>:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   classifier.fit(x_train,y_train)
# <ipython-input-73-a3aba1494452>:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   classifier.fit(x_train,y_train)
# <ipython-input-73-a3aba1494452>:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   classifier.fit(x_train,y_train)
# ...

# %%
acc_values
# Out:
# [0.8070640176600441,
#  0.8158940397350993,
#  0.8172185430463577,
#  0.8207505518763797,
#  0.8222958057395143,
#  0.8245033112582781,
#  0.8271523178807947,
#  0.8280353200883003,
#  0.830242825607064,
#  0.832008830022075,
#  0.8286975717439293,
#  0.8291390728476821]

# %%
plt.plot(neighbors,acc_values,'-o')
plt.xlabel('k values')
plt.ylabel('accuracy')
plt.grid()

# %%
classifier=KNeighborsClassifier(n_neighbors=12,metric='minkowski')
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)
print('accuracy: ',accuracy_score(y_test,y_pred))
# Out:
# <ipython-input-76-621f4bb7eaa9>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   classifier.fit(x_train,y_train)
# accuracy:  0.832008830022075

# %%
from sklearn.svm import SVC
lnr=SVC(kernel='linear')
lnr.fit(x_train,y_train)
y_pred=lnr.predict(x_test)
print('accuracy: ',accuracy_score(y_test,y_pred))
# Out:
# E:\anaconda\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# accuracy:  0.7980132450331126

# %%
poly=SVC(kernel='poly',degree=3)
poly.fit(x_train,y_train)
y_pred=poly.predict(x_test)
print('accuracy: ',accuracy_score(y_test,y_pred))
# Out:
# E:\anaconda\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# accuracy:  0.819205298013245

# %%
rbf=SVC(kernel='rbf')
rbf.fit(x_train,y_train)
y_pred=rbf.predict(x_test)
print('accuracy: ',accuracy_score(y_test,y_pred))
# Out:
# E:\anaconda\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# accuracy:  0.8381898454746137

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
print('accuracy: ',accuracy_score(y_test,y_pred))
# Out:
# accuracy:  0.7913907284768212

# %%
from sklearn.ensemble import RandomForestClassifier
rd=RandomForestClassifier()
rd.fit(x_train,y_train)
y_pred=rd.predict(x_test)
print('accuracy: ',accuracy_score(y_test,y_pred))
# Out:
# <ipython-input-81-038e84f26822>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rd.fit(x_train,y_train)
# accuracy:  0.8295805739514349

# %%
from sklearn.ensemble import GradientBoostingClassifier
gd=GradientBoostingClassifier()
gd.fit(x_train,y_train)
y_pred=gd.predict(x_test)
print('accuracy: ',accuracy_score(y_test,y_pred))
# Out:
# E:\anaconda\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# accuracy:  0.8523178807947019

# %%
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
# Out:
# E:\anaconda\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# GradientBoostingClassifier()

# %%
data
# Out:
#        age  workclass  education-num  marital-status  occupation  \
# 0       39          6             13               4           0
# 2       38          3              9               0           5
# 3       53          3              7               2           5
# 4       28          3             13               2           9
# 5       37          3             14               2           3
# ...    ...        ...            ...             ...         ...
# 32555   22          3             10               4          10
# 32556   27          3             12               2          12
# 32557   40          3              9               2           6
# 32558   58          3              9               6           0
# 32560   52          4              9               2           3
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0                 1     4    1          2174             0              40
# ...

# %%
data.value_counts()
# Out:
# age  workclass  education-num  marital-status  occupation  relationship  race  sex  capital-gain  capital-loss  hours-per-week  native-country  salary
# 33   3          9              2               2           0             4     1    0             0             40              38              0         16
# 35   3          9              2               2           0             4     1    0             0             40              38              0         15
# 39   3          9              2               2           0             4     1    0             0             40              38              0         14
# 51   3          9              2               2           0             4     1    0             0             40              38              0         14
# 20   8          10             4               9           3             4     0    0             0             40              38              0         14
# ...
